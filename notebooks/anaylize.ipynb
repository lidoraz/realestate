# %%
import sys
import os
sys.path.insert(0,f'/Users/{os.environ["USERNAME"]}/Documents/DS/Crypto')
from Twitter.connector import connect_remote_sql_alchemy

# %%
import matplotlib.pyplot as plt
import sqlite3
from pyproj import Transformer
import json
import pandas as pd
from datetime import datetime

# %%
conn = connect_remote_sql_alchemy()

# %%
# f"SELECT id, price, processing_date FROM yad2_forsale_history where id in"
#                  f" (select id from yad2_forsale_history where processing_date = '{datetime.today().strftime('%Y%m%d')}' or"
#                  f" processing_date = '{(datetime.today() - pd.to_timedelta('1D')).strftime('%Y%m%d')}')"

# df = pd.read_sql("SELECT id, price, processing_date FROM yad2_history", conn)

df_hist = pd.read_sql("select id, price, processing_date from yad2_forsale_history", conn)
print(df_hist.groupby('processing_date').size())
# Out:
# processing_date
# 2023-01-21    43872
# 2023-01-22     8303
# 2023-01-23     1555
# 2023-01-24     1164
# 2023-01-25     1360
# 2023-01-26     5272
# 2023-01-27     4498
# 2023-01-28     4759
# 2023-01-29     6022
# 2023-01-30     5820
# 2023-01-31     5808
# 2023-02-01     5757
# 2023-02-02     5550
# 2023-02-03     5000
# 2023-02-04     4672
# 2023-02-05     5986
# 2023-02-06     5896
# 2023-02-07     5775
# 2023-02-08     5869
# 2023-02-09     5655
# 2023-02-10     5768
# 2023-02-11     4743
# dtype: int64

# %%
info_cols = ['id', 'row_2', 'row_1', 'line_1', 'square_meters', 'line_2', 'neighborhood', 'merchant', 'assetclassificationid_text', 'coordinates', 'feed_source', 'address_more', 'search_text', 'date_added', 'date_updated']
df_today = pd.read_sql(f"Select {','.join(info_cols)} from yad2_today", conn)
print("Fetched rows:",len(df_today))
# Out:
# Fetched rows: 60801

# %%
# df_hist.to_pickle('resources/yad2_df_hist.pk')
# df_today.to_pickle('resources/yad2_df_today.pk')

# %%
# pd.read_sql(f"Select * from yad2_today limit 10", conn) # [['merchant', 'merchant_name']] # .columns # ['row_4']

# %%
df_today = df_today[~df_today['id'].duplicated()]
print("After rem dup:", len(df_today))
# Out:
# After rem dup: 54419

# %%
pd.to_datetime(df_today['date_added']).where(lambda x : x > pd.to_datetime('2022-01-01')).to_frame().set_index('date_added').resample('W').size().plot()
# Out:
# <AxesSubplot: xlabel='date_added'>

# %%
info_rename = dict(row_2='city', row_1='street', line_1='rooms', line_2='floor', assetclassificationid_text='status', search_text='info_text')
df_today['is_agency'] = df_today['feed_source'].apply(lambda x: True if x == 'commercial' else False if x == 'private' else None)
df_today = df_today.set_index('id').rename(columns=info_rename)
df_today['coordinates'] = df_today['coordinates'].apply(lambda x: json.loads(x.replace("'",'"')))
df_today['info_text'] = df_today['info_text'].apply(lambda x: x.split('תאור לקוח')[1] if len(x.split('תאור לקוח')) > 1 else None )

df_today['floor'] = df_today['floor'].apply(lambda x: 0 if x == 'קומת קרקע' else x.split(' ')[1].replace('-','')).astype(int)
df_today['rooms'] = df_today['rooms'].apply(lambda x: None if x == 'לא צויינו חדרים' else '1' if x == 'חדר אחד' else x.split(' ')[0]).astype(float)
df_today['type'] = df_today['city'].apply(lambda x: x.split(',')[0])
df_today['city_loc'] = df_today['city'].apply(lambda x: ','.join(x.split(',')[1:-1]))
df_today['city'] = df_today['city'].apply(lambda x: x.split(',')[-1])
df_today['lat'] = df_today['coordinates'].apply(lambda x: x.get('latitude'))
df_today['long'] = df_today['coordinates'].apply(lambda x: x.get('longitude'))

# %%
cols_order = ['type', 'city', 'city_loc', 'rooms', 'square_meters', 'floor',
       'status', 'is_agency', 'neighborhood', 'street',
       'address_more', 'info_text', 'date_added',  'lat', 'long', 'coordinates']

# %%
df_today = df_today[cols_order]

# %%
df_today.head()
# Out:
#                     type          city                   city_loc  rooms  \
# id
# sqovkhqg            דירה   תל אביב יפו                נווה אביבים    4.5
# 03osn0l8            דירה           ערד                               4.0
# qy17lshe  בית פרטי/קוטג'    זכרון יעקב                   גבעת עדן    6.0
# vtv2hc0t            דירה   ראשון לציון                    ראשונים    5.0
# mgu2c3ae            דירה        הרצליה   הרצליה הירוקה, נווה עובד    4.0
#
#           square_meters              neighborhood  floor  \
# id
# sqovkhqg          145.0               נווה אביבים      4
# 03osn0l8           95.0                       nan      6
# qy17lshe          215.0                  גבעת עדן      0
# vtv2hc0t          130.0                   ראשונים      4
# mgu2c3ae          100.0  הרצליה הירוקה, נווה עובד      2
#
#                            status is_agency                    street  \
# id
# sqovkhqg               דרוש שיפוץ      True               נווה אביבים
# 03osn0l8                    משופץ      True             אלעזר בן יאיר
# qy17lshe                    משופץ      True                  גבעת עדן
# vtv2hc0t               דרוש שיפוץ     False                טיומקין 19
# mgu2c3ae  חדש מקבלן (לא גרו בנכס)      True  הרצליה הירוקה, נווה עובד
#
#                       address_more  \
# id
# sqovkhqg              חדשה בשוק!!!
# 03osn0l8     4 חד מעלית מיזוג מידי
# qy17lshe                      None
# vtv2hc0t                      None
# mgu2c3ae  בשכונה חדשה במערב הרצליה
#
#                                                   info_text  \
# id
# sqovkhqg   בנווה אביבים, ברחוב לויטן  במיקום מעולה במרכז...
# 03osn0l8   4 חד שמורה מתאימה למגורים וגם להשכעה 4 חד מעל...
# qy17lshe   למכירה בגבעת עדן המבוקשת- בפרויקט טוסקנה .\nק...
# vtv2hc0t   מפרטי, ללא תיווך  - דירה מתוקה בבניין מקסים ב...
# mgu2c3ae   סנצ'ורי 21 - \nדירה חדשה שבנייתה הסתיימה זה ע...
#
#                    date_added        lat       long  \
# id
# sqovkhqg  2022-11-24 12:40:41  32.117652  34.797324
# 03osn0l8  2023-02-02 16:57:31  31.258166  35.209296
# qy17lshe  2023-01-19 10:19:02  32.586056  34.950434
# vtv2hc0t  2023-01-30 18:52:18  31.957828  34.803915
# mgu2c3ae  2022-07-26 12:19:40  32.170703  34.840096
#
#                                                 coordinates
# id
# sqovkhqg    {'latitude': 32.117652, 'longitude': 34.797324}
# 03osn0l8  {'latitude': 31.2581661643836, 'longitude': 35...
# qy17lshe    {'latitude': 32.586056, 'longitude': 34.950434}
# vtv2hc0t    {'latitude': 31.957828, 'longitude': 34.803915}
# mgu2c3ae    {'latitude': 32.170703, 'longitude': 34.840096}

# %%
df_hist = df_hist.dropna()
df_hist['price'] = df_hist['price'].astype(int)
# pd.options.display.float_format = '{:,.2f}'.format
df_hist = df_hist.drop_duplicates()

# %%
print(len(df_hist))
df = df_hist[df_hist['id'].isin(df_today.index)] # filter only to available ids
print(len(df))
# Out:
# 72865
# 57342

# %%
df_p = df.pivot(index='id', columns='processing_date', values='price')
df_p = df_p.ffill(axis=1).bfill(axis=1)

# %%
# ids[ids >3]

# %%
ids = df_hist.groupby('id').size()
ids = ids[ids > 1]
# ids.index

# %%
price_hist = df_hist[df_hist['id'].isin(ids.index)].sort_values(['id', 'processing_date']).groupby('id').agg(dict(price=list, processing_date=list))
price_hist.columns = ['price_hist', 'dt_hist']

# %%
# TODO: THIS IS BETTER FOR NOT HAVING FFILL AND BFILL for handling nulls
# df_p.apply(lambda x: (x[x.last_valid_index()] / x[x.first_valid_index()]) -1, axis=1).rename('price_pct')

# %%
price_pct = df_p.apply(lambda x: (x[-1] / x[0]) -1, axis=1).rename('price_pct')
price_diff = df_p.apply(lambda x: x[0] - x[-1], axis=1).rename('price_diff')
first_price = df_p.apply(lambda x: x[0], axis=1).rename('first_price')
last_price = df_p.apply(lambda x: x[-1], axis=1).rename('last_price')

# %%
df_metrics = pd.concat([first_price, last_price, price_diff, price_pct, price_hist], axis=1)

# %%
df_metrics.loc['01gxh9ad']
# Out:
# first_price                   1620000.0
# last_price                    1590000.0
# price_diff                      30000.0
# price_pct                     -0.018519
# price_hist           [1620000, 1590000]
# dt_hist        [2023-01-22, 2023-02-08]
# Name: 01gxh9ad, dtype: object

# %%
df = pd.concat([df_metrics, df_today[~df_today.index.duplicated()]], axis=1)

# %%
# df

# %%
df[df['price_pct'] < 0] # .sort_values()
# Out:
#           first_price  last_price  price_diff  price_pct          price_hist  \
# id
# 00n1qqk8    7200000.0   7150000.0     50000.0  -0.006944  [7200000, 7150000]
# 00yhxszq    3100000.0   3000000.0    100000.0  -0.032258  [3100000, 3000000]
# 01gxh9ad    1620000.0   1590000.0     30000.0  -0.018519  [1620000, 1590000]
# 01h2rpwz    1890000.0   1850000.0     40000.0  -0.021164  [1890000, 1850000]
# 01pikl3a    5850000.0   5650000.0    200000.0  -0.034188  [5850000, 5650000]
# ...               ...         ...         ...        ...                 ...
# zzcgzwmv    1520000.0   1490000.0     30000.0  -0.019737  [1520000, 1490000]
# zzib4jof    5100000.0   4800000.0    300000.0  -0.058824  [5100000, 4800000]
# zzkvylel    1700000.0   1690000.0     10000.0  -0.005882  [1700000, 1690000]
# zzmgslo8    3855000.0   3455000.0    400000.0  -0.103761  [3855000, 3455000]
# zzr01qdm    2430000.0   2400000.0     30000.0  -0.012346  [2430000, 2400000]
#
#                            dt_hist            type           city  \
# id
# 00n1qqk8  [2023-01-21, 2023-01-30]  בית פרטי/קוטג'      אור יהודה
# 00yhxszq  [2023-01-21, 2023-02-01]            דירה       ראש העין
# 01gxh9ad  [2023-01-22, 2023-02-08]            דירה           חיפה
# 01h2rpwz  [2023-02-08, 2023-02-09]            דירה        קרית גת
# 01pikl3a  [2023-01-21, 2023-01-24]  בית פרטי/קוטג'   יהוד מונוסון
# ...                            ...             ...            ...
# zzcgzwmv  [2023-01-21, 2023-01-24]            דירה         אשקלון
# zzib4jof  [2023-01-29, 2023-01-31]            דירה    תל אביב יפו
# zzkvylel  [2023-01-21, 2023-01-22]            דירה           חיפה
# zzmgslo8  [2023-01-25, 2023-02-04]  בית פרטי/קוטג'         אשקלון
# zzr01qdm  [2023-01-21, 2023-01-29]            דירה        ירושלים
#
#                    city_loc  rooms  ...  floor                   status  \
# id                                  ...
# 00n1qqk8                      12.5  ...    0.0                    משופץ
# 00yhxszq          פסגות אפק    5.0  ...    1.0           חדש (גרו בנכס)
# 01gxh9ad   קרית חיים מזרחית    3.0  ...    1.0           חדש (גרו בנכס)
# 01h2rpwz            כרמי גת    4.0  ...    5.0           חדש (גרו בנכס)
# 01pikl3a                       5.5  ...    0.0                    משופץ
# ...                     ...    ...  ...    ...                      ...
# zzcgzwmv          נווה אילן    4.0  ...    4.0                    משופץ
# zzib4jof        רמת אביב ג'    4.0  ...    2.0                במצב שמור
# zzkvylel              נעמ"ת    4.0  ...    2.0                במצב שמור
# zzmgslo8               ברנע    9.0  ...    0.0  חדש מקבלן (לא גרו בנכס)
# zzr01qdm               גילה    4.0  ...    1.0                    משופץ
#
#           is_agency            street                          address_more  \
# id
# 00n1qqk8       True         אור יהודה        דו משפחתי נמכר יחד 2 יחידות!!!
# 00yhxszq      False   נאדין גורדימר 9                                  None
# 01gxh9ad       True  קרית חיים מזרחית  3 חדרים חדשה באחריות קבלן אזור מבוקש
# 01h2rpwz      False      נחל ירקון 46                                  None
# 01pikl3a       True      יהוד מונוסון                                  None
# ...             ...               ...                                   ...
# zzcgzwmv       True         נווה אילן                             נוף לפארק
# zzib4jof       True       רמת אביב ג'                  ליד מרכז שוסטר. שקטה
# zzkvylel       True             שמשון                                  None
# zzmgslo8       True        הר מירון 5        מציאת המציאות600 מטר  מחוף הים
# zzr01qdm      False       יקינטון 575                                  None
#
#                                                   info_text  \
# id
# 00n1qqk8   דו משפחתי פינתי למכירה \nמחולק ל4  עם חצר גדו...
# 00yhxszq   בפרויקט האיכותי של פרשקובסקי, דירה גדולה ומרו...
# 01gxh9ad   בבניין מפואר אשר אוכלס לפני שנה במיקום מנצח ו...
# 01h2rpwz   הזדמנות מעולה! 50 אש"ח מתחת למחיר השוק.\n\nדי...
# 01pikl3a   דו משפחתי מקסים ומטופח. במיקום שקט וקרוב לכל ...
# ...                                                     ...
# zzcgzwmv   דירה מהממת באזור מושלם, יש * ממד * מרפסת לפאר...
# zzib4jof   דירה שקטה ליד מרכז שוסטר. חדרים מרווחים. נוף ...
# zzkvylel   נהדרת! דירה גדולה! בודדה בקומה, ארבעה כווני א...
# zzmgslo8   וילה על הים מגרש 400מטר ברנע  מציאאאאה הליכה ...
# zzr01qdm   דירת בוטיק. חצר פטיו פנימית. על ציר הרכבת הקל...
#
#                    date_added        lat       long  \
# id
# 00n1qqk8  2022-10-11 13:32:27  32.028492  34.857832
# 00yhxszq  2023-01-12 14:01:20  32.083268  34.962268
# 01gxh9ad  2023-01-19 15:33:43  32.822519  35.070471
# 01h2rpwz  2023-02-07 10:21:51  31.628025  34.770424
# 01pikl3a  2023-01-16 17:30:55  32.029254  34.879627
# ...                       ...        ...        ...
# zzcgzwmv  2023-01-06 10:38:34  31.666614  34.579157
# zzib4jof  2022-10-14 21:04:22  32.126064  34.802278
# zzkvylel  2022-12-05 18:47:33  32.795894  34.989289
# zzmgslo8  2019-08-18 14:14:45  31.682757  34.574087
# zzr01qdm  2022-12-05 17:47:45  31.737138  35.179907
#
#                                                 coordinates
# id
# 00n1qqk8    {'latitude': 32.028492, 'longitude': 34.857832}
# 00yhxszq    {'latitude': 32.083268, 'longitude': 34.962268}
# 01gxh9ad    {'latitude': 32.822519, 'longitude': 35.070471}
# 01h2rpwz    {'latitude': 31.628025, 'longitude': 34.770424}
# 01pikl3a    {'latitude': 32.029254, 'longitude': 34.879627}
# ...                                                     ...
# zzcgzwmv    {'latitude': 31.666614, 'longitude': 34.579157}
# zzib4jof    {'latitude': 32.126064, 'longitude': 34.802278}
# zzkvylel  {'latitude': 32.7958939428571, 'longitude': 34...
# zzmgslo8    {'latitude': 31.682757, 'longitude': 34.574087}
# zzr01qdm    {'latitude': 31.737138, 'longitude': 35.179907}
#
# [4746 rows x 22 columns]

# %%
df.query('last_price < 3000000 and -0.9 < price_pct < -0.01 and price_diff < 1e7').sort_values('price_pct')
# df.query('price_pct < -0.01').sort_values('price_pct')
# df.sort_values('price_pct')
# Out:
#           first_price  last_price  price_diff  price_pct  \
# id
# u4lpught    4400000.0   2500000.0   1900000.0  -0.431818
# b9buah4b    3950000.0   2875000.0   1075000.0  -0.272152
# 2lbj0nje    1500000.0   1100000.0    400000.0  -0.266667
# vld5cxmx    1350000.0    990000.0    360000.0  -0.266667
# cl39yw9b    3100000.0   2300000.0    800000.0  -0.258065
# ...               ...         ...         ...        ...
# ep17ylq6    2990000.0   2960000.0     30000.0  -0.010033
# wgwcisjt    1995000.0   1975000.0     20000.0  -0.010025
# n928o2j0    3000000.0   2970000.0     30000.0  -0.010000
# b0vcpxdj    1000000.0    990000.0     10000.0  -0.010000
# f60vg1sf    1000000.0    990000.0     10000.0  -0.010000
#
#                           price_hist                               dt_hist  \
# id
# u4lpught          [4400000, 2500000]              [2023-01-21, 2023-02-10]
# b9buah4b          [3950000, 2875000]              [2023-01-23, 2023-02-03]
# 2lbj0nje          [1500000, 1100000]              [2023-02-05, 2023-02-08]
# vld5cxmx  [1350000, 1080000, 990000]  [2023-01-21, 2023-01-25, 2023-02-04]
# cl39yw9b          [3100000, 2300000]              [2023-01-21, 2023-01-31]
# ...                              ...                                   ...
# ep17ylq6          [2990000, 2960000]              [2023-01-31, 2023-02-02]
# wgwcisjt          [1995000, 1975000]              [2023-01-21, 2023-02-06]
# n928o2j0          [3000000, 2970000]              [2023-01-21, 2023-01-30]
# b0vcpxdj           [1000000, 990000]              [2023-02-07, 2023-02-09]
# f60vg1sf           [1000000, 990000]              [2023-01-23, 2023-02-07]
#
#                     type           city              city_loc  rooms  ...  \
# id                                                                    ...
# u4lpught  בית פרטי/קוטג'        גן יבנה          גן יבנה מערב    5.0  ...
# b9buah4b            דירה         הרצליה                          4.0  ...
# 2lbj0nje            דירה    תל אביב יפו     הצפון הישן - דרום    1.0  ...
# vld5cxmx            דירה           חיפה      קרית חיים מזרחית    3.0  ...
# cl39yw9b            דירה    תל אביב יפו   צהלון, שיכוני חסכון    3.5  ...
# ...                  ...            ...                   ...    ...  ...
# ep17ylq6            דירה   יהוד מונוסון             ליבת העיר    5.0  ...
# wgwcisjt            דירה    ראשון לציון                 רמב"ם    3.5  ...
# n928o2j0            דירה          רעננה                          4.0  ...
# b0vcpxdj            דירה            צפת                  דרום    3.0  ...
# f60vg1sf            דירה         אשקלון             בן גוריון    5.0  ...
#
#           floor          status  is_agency            street  \
# id
# u4lpught    0.0  חדש (גרו בנכס)      False     רחל המשוררת 1
# b9buah4b    3.0       במצב שמור       True            הרצליה
# 2lbj0nje    0.0           משופץ      False       דיזנגוף 119
# vld5cxmx    1.0       במצב שמור       True  אהרון צייטלין 20
# cl39yw9b    0.0       במצב שמור       True        ציהתל"י 57
# ...         ...             ...        ...               ...
# ep17ylq6    3.0  חדש (גרו בנכס)       True       דרך העצמאות
# wgwcisjt    4.0           משופץ       True          בית יוסף
# n928o2j0    1.0           משופץ       True      אלימלך רימלט
# b0vcpxdj    1.0       במצב שמור       True              דרום
# f60vg1sf    3.0      דרוש שיפוץ       True          י.ל. פרץ
#
#                                          address_more  \
# id
# u4lpught                                         None
# b9buah4b                                  חניה בהסכמה
# 2lbj0nje  בדיזינגוף דירת חדר משופצת קומת קרקע עם גינה
# vld5cxmx                                   חנייה בשפע
# cl39yw9b                 יש חצר ענקית בהסכמה לא בטאבו
# ...                                               ...
# ep17ylq6        דירת חמישה חדרים הזדמנות לכניסה מהירה
# wgwcisjt                          מעלית וחניה בטאבו!!
# n928o2j0                                         None
# b0vcpxdj                                         None
# f60vg1sf                                         None
#
#                                                   info_text  \
# id
# u4lpught   מגרש, קרקע לבניית יחידה אחרונה בפרויקט יוקרתי...
# b9buah4b   מצויינת למשקיעים/זוגות צעירים\nדירת 4 חד \nחנ...
# 2lbj0nje   מפרטי ללא עמלת תיווך, בלב המדינה במיקום הכי מ...
# vld5cxmx   חדש למכירה בשיווק בלעדי.\nמשקיעים שימו לב.\nד...
# cl39yw9b   במיקום מעולה בלב יפו מיועדת לפינוי בינוי \nדי...
# ...                                                     ...
# ep17ylq6   למכירה דירת 5 חדרים ברחוב העצמאות\nבניין חדש ...
# wgwcisjt   בשכונת רמב"ם רחוב חד סיטרי שקט מאוד !! דירת 3...
# n928o2j0   חדש חדש . דירת 4 חדרים עברה שיפוץ כללי כולל ה...
# b0vcpxdj   דירה נעימה מאווררת ומוארת  \nבעלת  כיווני אוי...
# f60vg1sf   דירה מצויינת לחלוקה/מגורים\nבמיקום מצויין \nכ...
#
#                    date_added        lat       long  \
# id
# u4lpught  2022-12-30 13:20:24  31.790902  34.701631
# b9buah4b  2023-01-23 09:50:21  32.166778  34.842806
# 2lbj0nje  2023-02-05 11:00:16  32.080922  34.773599
# vld5cxmx  2022-12-30 19:09:04  32.817475  35.068930
# cl39yw9b  2022-12-20 11:31:16  32.038736  34.754927
# ...                       ...        ...        ...
# ep17ylq6  2022-10-23 19:41:47  32.027863  34.888157
# wgwcisjt  2022-10-26 09:38:04  31.964107  34.814274
# n928o2j0  2022-08-11 18:54:14  32.195521  34.850123
# b0vcpxdj  2023-01-11 14:48:30  32.958844  35.493469
# f60vg1sf  2023-01-23 14:56:44  31.656700  34.562831
#
#                                                 coordinates
# id
# u4lpught    {'latitude': 31.790902, 'longitude': 34.701631}
# b9buah4b    {'latitude': 32.166778, 'longitude': 34.842806}
# 2lbj0nje    {'latitude': 32.080922, 'longitude': 34.773599}
# vld5cxmx     {'latitude': 32.817475, 'longitude': 35.06893}
# cl39yw9b    {'latitude': 32.038736, 'longitude': 34.754927}
# ...                                                     ...
# ep17ylq6  {'latitude': 32.0278627567567, 'longitude': 34...
# wgwcisjt  {'latitude': 31.9641070909091, 'longitude': 34...
# n928o2j0  {'latitude': 32.1955205517241, 'longitude': 34...
# b0vcpxdj    {'latitude': 32.958844, 'longitude': 35.493469}
# f60vg1sf  {'latitude': 31.6566995833333, 'longitude': 34...
#
# [2567 rows x 22 columns]

# %%
# https://www.yad2.co.il/item/rsecw38q

# %%
df.loc['rsecw38q']
# Out:
# first_price                                              2990000.0
# last_price                                               2550000.0
# price_diff                                                440000.0
# price_pct                                                -0.147157
# price_hist                                      [2990000, 2550000]
# dt_hist                                   [2023-01-21, 2023-01-24]
# type                                                          דירה
# city                                                         נתניה
# city_loc                                            מרכז העיר דרום
# rooms                                                          4.0
# square_meters                                                130.0
# neighborhood                                        מרכז העיר דרום
# floor                                                          5.0
# status                                                   במצב שמור
# is_agency                                                     True
# street                                              מרכז העיר דרום
# address_more                                                  None
# info_text         בניין בוטיק מטופח המונה 6 דיירים בלבד! דירת 4...
# date_added                                     2022-08-24 14:11:11
# lat                                                      32.324624
# long                                                      34.85308
# coordinates         {'latitude': 32.324624, 'longitude': 34.85308}
# Name: rsecw38q, dtype: object

# %%
df.query('last_price < 3000000 and -0.9 < price_pct < -0.01 and price_diff < 1e7').sort_values('price_pct').head()
# Out:
#           first_price  last_price  price_diff  price_pct  \
# id
# u4lpught    4400000.0   2500000.0   1900000.0  -0.431818
# b9buah4b    3950000.0   2875000.0   1075000.0  -0.272152
# 2lbj0nje    1500000.0   1100000.0    400000.0  -0.266667
# vld5cxmx    1350000.0    990000.0    360000.0  -0.266667
# cl39yw9b    3100000.0   2300000.0    800000.0  -0.258065
#
#                           price_hist                               dt_hist  \
# id
# u4lpught          [4400000, 2500000]              [2023-01-21, 2023-02-10]
# b9buah4b          [3950000, 2875000]              [2023-01-23, 2023-02-03]
# 2lbj0nje          [1500000, 1100000]              [2023-02-05, 2023-02-08]
# vld5cxmx  [1350000, 1080000, 990000]  [2023-01-21, 2023-01-25, 2023-02-04]
# cl39yw9b          [3100000, 2300000]              [2023-01-21, 2023-01-31]
#
#                     type          city              city_loc  rooms  ...  \
# id                                                                   ...
# u4lpught  בית פרטי/קוטג'       גן יבנה          גן יבנה מערב    5.0  ...
# b9buah4b            דירה        הרצליה                          4.0  ...
# 2lbj0nje            דירה   תל אביב יפו     הצפון הישן - דרום    1.0  ...
# vld5cxmx            דירה          חיפה      קרית חיים מזרחית    3.0  ...
# cl39yw9b            דירה   תל אביב יפו   צהלון, שיכוני חסכון    3.5  ...
#
#           floor          status  is_agency            street  \
# id
# u4lpught    0.0  חדש (גרו בנכס)      False     רחל המשוררת 1
# b9buah4b    3.0       במצב שמור       True            הרצליה
# 2lbj0nje    0.0           משופץ      False       דיזנגוף 119
# vld5cxmx    1.0       במצב שמור       True  אהרון צייטלין 20
# cl39yw9b    0.0       במצב שמור       True        ציהתל"י 57
#
#                                          address_more  \
# id
# u4lpught                                         None
# b9buah4b                                  חניה בהסכמה
# 2lbj0nje  בדיזינגוף דירת חדר משופצת קומת קרקע עם גינה
# vld5cxmx                                   חנייה בשפע
# cl39yw9b                 יש חצר ענקית בהסכמה לא בטאבו
#
#                                                   info_text  \
# id
# u4lpught   מגרש, קרקע לבניית יחידה אחרונה בפרויקט יוקרתי...
# b9buah4b   מצויינת למשקיעים/זוגות צעירים\nדירת 4 חד \nחנ...
# 2lbj0nje   מפרטי ללא עמלת תיווך, בלב המדינה במיקום הכי מ...
# vld5cxmx   חדש למכירה בשיווק בלעדי.\nמשקיעים שימו לב.\nד...
# cl39yw9b   במיקום מעולה בלב יפו מיועדת לפינוי בינוי \nדי...
#
#                    date_added        lat       long  \
# id
# u4lpught  2022-12-30 13:20:24  31.790902  34.701631
# b9buah4b  2023-01-23 09:50:21  32.166778  34.842806
# 2lbj0nje  2023-02-05 11:00:16  32.080922  34.773599
# vld5cxmx  2022-12-30 19:09:04  32.817475  35.068930
# cl39yw9b  2022-12-20 11:31:16  32.038736  34.754927
#
#                                               coordinates
# id
# u4lpught  {'latitude': 31.790902, 'longitude': 34.701631}
# b9buah4b  {'latitude': 32.166778, 'longitude': 34.842806}
# 2lbj0nje  {'latitude': 32.080922, 'longitude': 34.773599}
# vld5cxmx   {'latitude': 32.817475, 'longitude': 35.06893}
# cl39yw9b  {'latitude': 32.038736, 'longitude': 34.754927}
#
# [5 rows x 22 columns]

# %%
df.loc['ojtkf58r'] # ['info_text']
# Out:
# first_price                                              1135000.0
# last_price                                               1235000.0
# price_diff                                               -100000.0
# price_pct                                                 0.088106
# price_hist                    [1135000, 1155000, 1225000, 1235000]
# dt_hist           [2023-01-21, 2023-01-26, 2023-01-29, 2023-01-31]
# type                                                          דירה
# city                                                       באר שבע
# city_loc                                                 שכונה י"א
# rooms                                                          4.5
# square_meters                                                101.0
# neighborhood                                             שכונה י"א
# floor                                                          1.0
# status                                                       משופץ
# is_agency                                                    False
# street                                                   החיד"א 63
# address_more                                                  None
# info_text         אפשרות לרהוט מלא. להתקשר רק בואצאפ שנגמר שרשו...
# date_added                                     2022-11-27 02:32:51
# lat                                                      31.253254
# long                                                     34.767835
# coordinates        {'latitude': 31.253254, 'longitude': 34.767835}
# Name: ojtkf58r, dtype: object

# %%
df['price_hist']
# Out:
# id
# 000lge5g    [2700000, 2750000, 2800000]
# 001hfol0                            NaN
# 001hv94y                            NaN
# 0021e7ng                            NaN
# 003iem8d                            NaN
#                        ...
# wiiyrpt4                            NaN
# fv5ma67f                            NaN
# a9m0dcrw                            NaN
# jjnptsrv                            NaN
# 0cw8yygx                            NaN
# Name: price_hist, Length: 55292, dtype: object

# %%
df[df['price_hist'].apply(lambda x: len(x) if isinstance(x, list) else 0) >= 3].dropna(subset='last_price').sort_values('price_pct', ascending=False)[10:]
# Out:
#            first_price  last_price    price_diff  price_pct  \
# id
# i8354d5f  3.500000e+06   3950000.0 -4.500000e+05   0.128571
# qcvw7lfe  7.100000e+06   8000000.0 -9.000000e+05   0.126761
# lzoju8xi  3.700000e+06   4100000.0 -4.000000e+05   0.108108
# tiiz1ax0  3.700000e+06   4100000.0 -4.000000e+05   0.108108
# raivy02m  4.595000e+06   5075000.0 -4.800000e+05   0.104461
# ...                ...         ...           ...        ...
# 2y33r22x  1.390000e+07   7500000.0  6.400000e+06  -0.460432
# rpmntjz0  4.800000e+07   4690000.0  4.331000e+07  -0.902292
# n7hkipyd  2.700000e+06    100000.0  2.600000e+06  -0.962963
# ulk5vn6v  3.500000e+06     12345.0  3.487655e+06  -0.996473
# jm1ajoh4  2.900000e+09   3100000.0  2.896900e+09  -0.998931
#
#                                     price_hist  \
# id
# i8354d5f           [3500000, 3800000, 3950000]
# qcvw7lfe           [7100000, 6100000, 8000000]
# lzoju8xi           [3700000, 3500000, 4100000]
# tiiz1ax0  [3700000, 4200000, 3800000, 4100000]
# raivy02m           [4595000, 5150000, 5075000]
# ...                                        ...
# 2y33r22x          [13900000, 6500000, 7500000]
# rpmntjz0          [48000000, 4750000, 4690000]
# n7hkipyd            [2700000, 2600000, 100000]
# ulk5vn6v               [3500000, 51234, 12345]
# jm1ajoh4        [2900000000, 2900000, 3100000]
#
#                                                    dt_hist            type  \
# id
# i8354d5f              [2023-01-21, 2023-01-22, 2023-01-23]      גג/פנטהאוז
# qcvw7lfe              [2023-01-21, 2023-01-22, 2023-02-09]            דירה
# lzoju8xi              [2023-01-22, 2023-01-29, 2023-02-08]  בית פרטי/קוטג'
# tiiz1ax0  [2023-01-21, 2023-01-30, 2023-02-06, 2023-02-08]            דירה
# raivy02m              [2023-01-21, 2023-02-03, 2023-02-08]      גג/פנטהאוז
# ...                                                    ...             ...
# 2y33r22x              [2023-01-23, 2023-01-26, 2023-02-03]  משק חקלאי/נחלה
# rpmntjz0              [2023-01-21, 2023-01-22, 2023-02-08]      גג/פנטהאוז
# n7hkipyd              [2023-02-01, 2023-02-05, 2023-02-09]            דירה
# ulk5vn6v              [2023-01-21, 2023-02-05, 2023-02-06]            דירה
# jm1ajoh4              [2023-01-21, 2023-01-22, 2023-01-25]            דירה
#
#                   city                 city_loc  rooms  ...  floor  \
# id                                                      ...
# i8354d5f         טבריה             שיכון עובדים    5.5  ...   10.0
# qcvw7lfe   תל אביב יפו   גני שרונה, קרית הממשלה    5.0  ...   20.0
# lzoju8xi        נתיבות              נתיבות מערב    5.0  ...    0.0
# tiiz1ax0   תל אביב יפו        מונטיפיורי, הרכבת    3.0  ...   33.0
# raivy02m         בת ים       דרום חדש, פארק הים    5.0  ...   29.0
# ...                ...                      ...    ...  ...    ...
# 2y33r22x         מגדים                             NaN  ...    0.0
# rpmntjz0     פתח תקווה               כפר גנים ג    5.0  ...    8.0
# n7hkipyd   תל אביב יפו                 נווה שרת    2.0  ...    3.0
# ulk5vn6v        הרצליה                             2.0  ...    6.0
# jm1ajoh4        רחובות                   שעריים    5.0  ...    7.0
#
#                            status  is_agency             street  \
# id
# i8354d5f           חדש (גרו בנכס)      False            מורן 14
# qcvw7lfe  חדש מקבלן (לא גרו בנכס)      False   אוסוולדו ארניה 2
# lzoju8xi           חדש (גרו בנכס)      False        כפר דרום 15
# tiiz1ax0           חדש (גרו בנכס)       True  דרך מנחם בגין 144
# raivy02m           חדש (גרו בנכס)      False         נעמי שמר 6
# ...                           ...        ...                ...
# 2y33r22x                במצב שמור       True              מגדים
# rpmntjz0           חדש (גרו בנכס)       True            יפה נוף
# n7hkipyd                    משופץ      False           בית אל 5
# ulk5vn6v                במצב שמור       True             הרצליה
# jm1ajoh4                    משופץ      False      מרים מזרחי 20
#
#                                        address_more  \
# id
# i8354d5f                                       None
# qcvw7lfe                                       None
# lzoju8xi                                       None
# tiiz1ax0                 MIDTOWN TLV | משורר השקעות
# raivy02m                                       None
# ...                                             ...
# 2y33r22x                                       None
# rpmntjz0                                       None
# n7hkipyd                                       None
# ulk5vn6v  דירה מהממת עסקה נדלן מעולה להשקעה ומגורים
# jm1ajoh4                                       None
#
#                                                   info_text  \
# id
# i8354d5f   פנטהאוז יוקרתי בשלושה מפלסים, קומה ראשונה סלו...
# qcvw7lfe   הערכת שמאי עדכנית  1 9 מיליון.\r\nבמגדלי בסר ...
# lzoju8xi   וילה באזור יוקרתי עם open space  מטורף \nבמטב...
# tiiz1ax0   למכירה במגדל MIDTOWN TLV !\nדירת 3 חדרים כ - ...
# raivy02m   דירת מיני פנטהאוז בצמרת המגדל! \r\nקו ראשון ל...
# ...                                                     ...
# 2y33r22x   נחלה יפה  !\nמיקום שקט וטוב\n3.5 חלקה צהובה ,...
# rpmntjz0   מני פנטהאוז מרהיב ביופיו דירת 5 חד שהפכו ל4 ג...
# n7hkipyd   דירה מיוחדת*מוארת*לא בבניין "רכבת"\n*קרובה לכ...
# ulk5vn6v   דירה במלון הרצליה פיתוח השקעה מעולה \n2 חד די...
# jm1ajoh4   דירה מושלמת 5 חדרים מרווחים מאוד. הבית 120 מט...
#
#                    date_added        lat       long  \
# id
# i8354d5f  2022-03-08 20:46:46  32.799881  35.518551
# qcvw7lfe  2022-11-12 11:50:23  32.073147  34.786051
# lzoju8xi  2022-02-25 12:42:25  31.419452  34.567526
# tiiz1ax0  2022-12-08 14:25:46  32.077662  34.793063
# raivy02m  2023-01-12 00:42:25  32.006530  34.740614
# ...                       ...        ...        ...
# 2y33r22x  2023-01-22 21:23:23  32.729022  34.959158
# rpmntjz0  2023-01-20 11:58:04  32.076842  34.862685
# n7hkipyd  2023-01-31 23:39:10  32.118479  34.838596
# ulk5vn6v  2023-01-16 15:55:52  32.166778  34.842806
# jm1ajoh4  2023-01-18 21:30:05  31.890962  34.815849
#
#                                                 coordinates
# id
# i8354d5f    {'latitude': 32.799881, 'longitude': 35.518551}
# qcvw7lfe    {'latitude': 32.073147, 'longitude': 34.786051}
# lzoju8xi    {'latitude': 31.419452, 'longitude': 34.567526}
# tiiz1ax0    {'latitude': 32.077662, 'longitude': 34.793063}
# raivy02m     {'latitude': 32.00653, 'longitude': 34.740614}
# ...                                                     ...
# 2y33r22x    {'latitude': 32.729022, 'longitude': 34.959158}
# rpmntjz0  {'latitude': 32.0768416346154, 'longitude': 34...
# n7hkipyd    {'latitude': 32.118479, 'longitude': 34.838596}
# ulk5vn6v    {'latitude': 32.166778, 'longitude': 34.842806}
# jm1ajoh4    {'latitude': 31.890962, 'longitude': 34.815849}
#
# [671 rows x 22 columns]

# %%
import numpy as np
def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    if to_radians:
        lat1, lon1 = np.radians([lat1, lon1])
        lat2, lon2 = np.radians([lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a))
def calc_dist(df, deal, distance):
    dist = haversine(df['lat'], df['long'], deal['lat'], deal['long'])
    df['dist'] = dist
    df = df[df['dist'] < distance]
    return df

# %%
con_taxes = sqlite3.connect('resources/nadlan.db')

# %%
def get_similar_closed_deals(deal, days_back, dist_km, with_room):
    if np.isnan(deal['lat']) or np.isnan(deal['long']):
        raise ValueError('lat or long are not valid')
    wgs84_itm_to_trans = Transformer.from_crs(4326, 2039)
    cor_x, cor_y = wgs84_itm_to_trans.transform(deal['lat'], deal['long'])
    # print(cor_x, cor_y)
    dt_back = (datetime.today() - pd.to_timedelta(f'{days_back}D')).strftime('%Y%m%d')
    sql_dist_cond = f'and sqrt((pow(corX - {cor_x}, 2) + pow(corY - {cor_y}, 2))/1000000)'
    sql_room_cond = f"and round(misHadarim) = round({deal['rooms']})" if with_room else ""
    q = f'select {sql_dist_cond.split("and")[1]} as dist_from_deal, *  from trans where tariska > {dt_back}' \
        f' {sql_dist_cond} < {dist_km}'\
        f' {sql_room_cond}'\
        f' and helekNimkar = 1.0'
    # print(q)
    df_tax = pd.read_sql(q, con_taxes)
    return df_tax

def plot_deal_vs_sale_sold(other_close_deals, df_tax, deal):
    # When the hist becomes square thats because there a huge anomaly in terms of extreme value
    sale_items = other_close_deals[other_close_deals['rooms'] == deal['rooms']]['last_price']
    sale_items.rename(f'last_price #{len(sale_items)}').hist(bins=min(70, len(sale_items)), legend=True, alpha=0.8)
    sold_items = df_tax['mcirMorach']
    if len(sold_items):
        sold_items.rename(f'realPrice{days_back}D #{len(sold_items)}').hist(bins=min(70, len(sold_items)), legend=True, alpha=0.8)
    plt.axvline(deal['last_price'], color='red', label=f"{deal['last_price']:,.0f}", linewidth=2)
    str_txt = f"{'חדרים'[::-1]} {deal['rooms']},{deal['type'][::-1]}, {deal['street'][::-1]}, {deal['city'][::-1]}, {deal['price_pct']:0.2%}"
    plt.xlim([deal['last_price'] // 2, deal['last_price'] * 3])
    plt.title(str_txt)
    plt.legend()
    plt.show()

# %%
deal_id = np.random.choice(df[df['price_pct'] < 0].index)
# deal_id = 'yu16k5yx'
# deal_id = 'zct9jz2a'
# deal_id = 'vgnsg6pf'
# deal_id = 'omresoki'
assert deal_id in df.index

# %%
days_back = 99
dist_km = 1
deal = df.loc[deal_id]
other_close_deals = calc_dist(df, deal, dist_km) # .join(df)
other_close_deals = other_close_deals.dropna(subset='rooms')
other_close_deals = other_close_deals[other_close_deals['rooms'].astype(float).astype(int) == int(float(deal['rooms']))]
df_tax = get_similar_closed_deals(deal, days_back, dist_km, True)
# display(df_tax)
plot_deal_vs_sale_sold(other_close_deals, df_tax, deal)
from IPython.display import display, HTML
maps_url = f"http://maps.google.com/maps?z=12&t=m&q=loc:{deal['lat']}+{deal['long']}&hl=iw" # ?hl=iw, t=k sattalite
display(HTML(f"""<a href="https://www.yad2.co.il/item/{deal.name}">LINK TO DIRA!!</a> $$$ <a href="{maps_url}">LINK TO DIRA IN MAPS</a>"""))
print(deal['info_text'])
days_online = (datetime.today() - pd.to_datetime(deal['date_added'])).days
display(days_online)
display(df_tax.sort_values('mcirMozhar'))
display(other_close_deals[other_close_deals['rooms'].astype(float).astype(int) == int(float(deal['rooms']))].dropna(subset='price_pct').sort_values('last_price'))
deal
# Out:
# <a href="https://www.yad2.co.il/item/38rzna9n">LINK TO DIRA!!</a> $$$ <a href="http://maps.google.com/maps?z=12&t=m&q=loc:32.0712418913043+34.7664990652174&hl=iw">LINK TO DIRA IN MAPS</a>
#  4 חדרים 92 מ"ר נטו + מרפסת שמש גדולה 35 מר מהסלון + מרפסת שמש מחדר השינה , שירותים ומקלחת כפולים , בניין לשימור שעבר חידוש , מעלית וחניה בטאבו תיקרה גבוה 3.3 מ מיקום מעולה בבניין חדיש שעבר שימור סוקולוב נכסים הינו משרד תיווך דירות הפועל ברציפות למעלה מ-29 שנים , במתן דגש על ליווי ושירות מהטובים שיש בתחום, אמינות ומקצועיות , בכל הרשור להערכת נכסים ומכירתם , יזמויות ואיתור השקעות מניבות . סוכנות סוקולוב נכסים
# 97
#    dist_from_deal             ezor                gush   tarIska  \
# 0        0.521335  50 - מק-תל אביב  007002-0037-232-00  20221122
#
#          yeshuv  rechov bayit knisa dira  mcirMozhar  ...  tifkudBnyn  \
# 0  תל אביב -יפו  הירקון     2    --  232    44071425  ...      מגורים
#
#       tifkudYchida          shumaHalakim  mofaGush  tava          mahutZchut  \
# 0  דירה בבית קומות  1 / 1 ליחידה בשלמותה         0    --  בעלות כפופה לחכירה
#
#    helekNimkar    corX    corY               insertionDate
# 0          1.0  177866  663839  2023-01-13 16:01:52.978786
#
# [1 rows x 31 columns]
#           first_price  last_price  price_diff  price_pct          price_hist  \
# id
# q9gj85x4      30000.0     30000.0         0.0     0.0000                 NaN
# kaowwtqu    2400000.0   2250000.0    150000.0    -0.0625  [2400000, 2250000]
# l50j5to8    3600000.0   3600000.0         0.0     0.0000                 NaN
# zssjyau0    3900000.0   3900000.0         0.0     0.0000                 NaN
# w77k2u5q    4500000.0   4500000.0         0.0     0.0000                 NaN
# ...               ...         ...         ...        ...                 ...
# zkowwydi   30000000.0  30000000.0         0.0     0.0000                 NaN
# phs6p7     32000000.0  32000000.0         0.0     0.0000                 NaN
# t6onaui6   33000000.0  33000000.0         0.0     0.0000                 NaN
# 6z4e58oq   34000000.0  34000000.0         0.0     0.0000                 NaN
# rmgyuyvw   45000000.0  45000000.0         0.0     0.0000                 NaN
#
#                            dt_hist            type          city  \
# id
# q9gj85x4                       NaN  בית פרטי/קוטג'   תל אביב יפו
# kaowwtqu  [2023-01-21, 2023-01-22]            דירה   תל אביב יפו
# l50j5to8                       NaN            דירה   תל אביב יפו
# zssjyau0                       NaN            דירה   תל אביב יפו
# w77k2u5q                       NaN            דירה   תל אביב יפו
# ...                            ...             ...           ...
# zkowwydi                       NaN      גג/פנטהאוז   תל אביב יפו
# phs6p7                         NaN            דירה   תל אביב יפו
# t6onaui6                       NaN            דירה   תל אביב יפו
# 6z4e58oq                       NaN            דירה   תל אביב יפו
# rmgyuyvw                       NaN            דירה   תל אביב יפו
#
#                            city_loc  rooms  ...          status is_agency  \
# id                                          ...
# q9gj85x4                   נווה צדק    4.0  ...       במצב שמור      True
# kaowwtqu                               4.0  ...       במצב שמור      True
# l50j5to8          הצפון הישן - דרום    4.0  ...       במצב שמור      True
# zssjyau0                כרם התימנים    4.0  ...           משופץ     False
# w77k2u5q   לב תל אביב, לב העיר צפון    4.0  ...           משופץ      True
# ...                             ...    ...  ...             ...       ...
# zkowwydi                               4.0  ...  חדש (גרו בנכס)      True
# phs6p7                  כרם התימנים    4.0  ...  חדש (גרו בנכס)      True
# t6onaui6                               4.0  ...           משופץ      True
# 6z4e58oq                כרם התימנים    4.0  ...  חדש (גרו בנכס)      True
# rmgyuyvw                               4.0  ...  חדש (גרו בנכס)      True
#
#                             street  \
# id
# q9gj85x4                  נווה צדק
# kaowwtqu               טשרניחובסקי
# l50j5to8                     המליץ
# zssjyau0           הרב אהרונסון 31
# w77k2u5q  לב תל אביב, לב העיר צפון
# ...                            ...
# zkowwydi          רציף הרברט סמואל
# phs6p7                 כרם התימנים
# t6onaui6          רציף הרברט סמואל
# 6z4e58oq                 הירקון 19
# rmgyuyvw          רציף הרברט סמואל
#
#                                                address_more  \
# id
# q9gj85x4  בהזדמנות ליזמים במיקום מבוקש בית+מגרש לבניה רוויה
# kaowwtqu                                           בלב ת''א
# l50j5to8                                               None
# zssjyau0                                               None
# w77k2u5q                                               None
# ...                                                     ...
# zkowwydi                                               None
# phs6p7                                                 None
# t6onaui6                                               None
# 6z4e58oq                                               None
# rmgyuyvw            למכירה דירת פאר על הים ת''א הרברט סמואל
#
#                                                   info_text  \
# id
# q9gj85x4   עסקה מעניינת ליזמים / קבלנים!!! במיקום נדיר ו...
# kaowwtqu   למכירה נכס מסחרי בקומת מרתף, \nבמיקום הכי מבו...
# l50j5to8   דירה גדולה\r\nמחיר מעולה\r\nלשיפוץ סוכנות נכס...
# zssjyau0     דירה בדמי מפתח\n4 חדרים גדולים \n200 מטר מהים
# w77k2u5q   בלב העיר! בקרבת שד' רוטשילד!\nדירת 4 חדרים מר...
# ...                                                     ...
# zkowwydi   פנינת הים -פנטאהוז -4 חדרים +משרד-בבלעדיות של...
# phs6p7     דירה מהממת -כולל מרפסות 322 מ"ר , משופצת כחדש...
# t6onaui6   דירת לופט יוקרתית בבניין היוקרתי בקו החוף , \...
# 6z4e58oq   ברויאל ביץ' רזידנס SEA ONE\n\n200 מ"ר פלוס 24...
# rmgyuyvw   למכירה דירת פאר על הים תל אביב הרברט סמואל, ה...
#
#                    date_added        lat       long  \
# id
# q9gj85x4  2022-12-19 21:47:16  32.063260  34.763762
# kaowwtqu  2022-05-15 13:28:28  32.073304  34.772138
# l50j5to8  2020-06-25 10:03:25  32.074857  34.774261
# zssjyau0  2022-08-10 19:38:05  32.070690  34.766595
# w77k2u5q  2023-01-15 12:51:56  32.070137  34.773903
# ...                       ...        ...        ...
# zkowwydi  2019-08-18 14:14:45  32.073873  34.765202
# phs6p7    2019-08-18 14:14:45  32.070405  34.766457
# t6onaui6  2022-08-14 19:45:10  32.073873  34.765202
# 6z4e58oq  2021-07-04 15:02:53  32.070285  34.764652
# rmgyuyvw  2022-05-26 11:36:54  32.073873  34.765202
#
#                                                 coordinates      dist
# id
# q9gj85x4     {'latitude': 32.06326, 'longitude': 34.763762}  0.924260
# kaowwtqu  {'latitude': 32.0733041132075, 'longitude': 34...  0.578726
# l50j5to8    {'latitude': 32.074857, 'longitude': 34.774261}  0.834549
# zssjyau0     {'latitude': 32.07069, 'longitude': 34.766595}  0.062030
# w77k2u5q    {'latitude': 32.070137, 'longitude': 34.773903}  0.708378
# ...                                                     ...       ...
# zkowwydi  {'latitude': 32.0738726504854, 'longitude': 34...  0.317036
# phs6p7      {'latitude': 32.070405, 'longitude': 34.766457}  0.093142
# t6onaui6  {'latitude': 32.0738726504854, 'longitude': 34...  0.317036
# 6z4e58oq    {'latitude': 32.070285, 'longitude': 34.764652}  0.203989
# rmgyuyvw  {'latitude': 32.0738726504854, 'longitude': 34...  0.317036
#
# [233 rows x 23 columns]
# first_price                                              5850000.0
# last_price                                               5500000.0
# price_diff                                                350000.0
# price_pct                                                -0.059829
# price_hist                                      [5850000, 5500000]
# dt_hist                                   [2023-01-21, 2023-02-01]
# type                                                          דירה
# city                                                   תל אביב יפו
# city_loc                                               כרם התימנים
# rooms                                                          4.0
# square_meters                                                125.0
# neighborhood                                           כרם התימנים
# floor                                                          3.0
# status                                                       משופץ
# is_agency                                                     True
# street                                                     הרב קוק
# address_more                                בבניין חדיש שעבר שימור
# info_text         4 חדרים 92 מ"ר נטו + מרפסת שמש גדולה 35 מר מה...
# date_added                                     2022-11-06 16:04:33
# lat                                                      32.071242
# long                                                     34.766499
# coordinates      {'latitude': 32.0712418913043, 'longitude': 34...
# Name: 38rzna9n, dtype: object

# %%
other_close_deals['last_price'].median()
# Out:
# 8300000.0

# %%
# pip install swifter

# %%
# pip install pandas-parallel-apply
#pip install pathos
from pandas_parallel_apply import DataFrameParallel
# dfp = DataFrameParallel(df, pbar=False)
# asdf2 = dfp.apply(f, axis=1)

# %%
def get_metrics(deal):
    try:
        other_close_deals = calc_dist(df, deal, dist_km) # .join(df)
        other_close_deals = other_close_deals[other_close_deals['rooms'].astype(float).astype(int) == int(float(deal['rooms']))]
        # print(deal['last_price'], other_close_deals['last_price'].median())
        pct = deal['last_price'] / other_close_deals['last_price'].median() - 1
        length = len(other_close_deals)
    except:
        pct = None
        length = 0
    return (pct, length)

# %%
# import swifter
# swifter.set_defaults(force_parallel=True)

# %%
pd.to_datetime(df_today['date_added']).max()
# Out:
# Timestamp('2023-02-11 20:00:09')

# %%
pd.to_datetime(df['date_added']).max()
# Out:
# Timestamp('2023-02-11 20:00:09')

# %%
dfp = DataFrameParallel(df, n_cores=8, pbar=True)
out = dfp.apply(get_metrics, axis=1)
# df.swifter.apply(get_metrics, axis=1)

# %%
df = df.join(pd.DataFrame(out.tolist(), columns=['pct_diff_median','group_size'], index=out.index))

# %%
# pd.DataFrame(out.tolist(), columns=['pct_diff_median','group_size'], index=out.index)

# %%
df['rooms'] = df['rooms'].astype(float)

# %%
df.to_pickle('resources/yad2_df.pk')

# %%
df['status'].value_counts()
# Out:
# משופץ                      19952
# במצב שמור                  15451
# חדש (גרו בנכס)              9269
# חדש מקבלן (לא גרו בנכס)     7229
# דרוש שיפוץ                  2516
# nan                            2
# Name: status, dtype: int64

# %%
df.query('price_pct < 0').to_csv('yad2_df_discount.csv')

# %%
df.to_csv('yad2_df.csv')

# %%
df_hist_t= df_hist.groupby('id')['processing_date'].max()

# %%
df_hist_t[~df_hist_t.index.isin(df_today.index)]

# %%
import pandas as pd
df = pd.read_pickle('resources/yad2_df.pk')

# %%
df.loc['nt8i5pyj']

# %%
import requests
res = requests.get('https://gw.yad2.co.il/feed-search-legacy/item?token=0v6qzomt')

# %%
res = requests.get('https://gw.yad2.co.il/feed-search-legacy/item?token={}'.format(item))
d = res.json()['data']
items_v2 = {x['key']: x['value'] for x in d['additional_info_items_v2']}
add_info = dict(parking = int(d['parking']),
                balconies = d['balconies'],
                renovated = items_v2['renovated'],
                elevator = d['analytics_items']['elevator'],
                storeroom = d['analytics_items']['storeroom'],
                number_of_floors = d['analytics_items']['number_of_floors'],
                shelter = d['analytics_items']['shelter_room'],
                immediate = d['analytics_items']['immediate'],
                info_text = d['info_text']
               )
return add_info
# parking = d['parking']
# balconies = d['balconies']
# renovated = items_v2['renovated']
# elevator = d['analytics_items']['elevator']
# shelter = d['analytics_items']['shelter_room']
# number_of_floors = d['analytics_items']['number_of_floors']
# immediate = d['analytics_items']['immediate']
# storeroom = d['analytics_items']['storeroom']
# info_text = d['info_text']

# %%
add_info

# %%
res.json()['data']['analytics_items']

# %%
df.sort_values('pct_diff_median').query('group_size > 30 '
                                             'and 2 < rooms < 5'
                                             ' and last_price > 500000'
                                             ' and pct_diff_median < -0.1')[:60]

# %%
other_close_deals['rooms'].astype(float).astype(int)

# %%
# other_close_deals

# %%
# df_tax.sort_values('mcirMorach', ascending=False)

# %%
display(HTML(f"""<a href="https://www.yad2.co.il/item/{'298sxaie'}">NICE APERTMENT LINK TO DIRA!!</a>"""))

# %%
# https://www.yad2.co.il/item/298sxaie
# https://www.yad2.co.il/item/ceec8bob

# %%
# https://www.yad2.co.il/item/omresoki?utm_source=dooron&utm_medium=internal&utm_campaign=dooron-ad-view&openedFrom=Dooron

# %%
pd.read_sql("SHOW CREATE TABLE yad2_history", conn)

# %%
import pandas as pd
df_all_history = pd.read_sql("SELECT * FROM yad2_history", conn)

# %%
pd.DataFrame([datetime.today().date()]).dtypes

# %%
df_all_history_t = df_all_history.copy()

# %%
df_all_history_t['processing_date'] = pd.to_datetime(df_all_history_t['processing_date'])

# %%
# df_all_history_t['id'].nunique()
df_all_history_t['id'].nunique()

# %%
df_all_history_t.sort_values(['id', 'processing_date']).groupby(['id','price']).first() # .reset_index()['id'].value_counts()

# %%
df_all_history.loc['5lfffhj6']

# %%
df_all_history_t_a = df_all_history_t.sort_values(['id', 'processing_date']).groupby(['id','price']).first().reset_index()

# %%
df_all_history_t_a['id'].value_counts()

# %%
df_all_history_t_a

# %%
conn.cursor().execute(
        "CREATE TABLE IF NOT EXISTS yad2_history(id VARCHAR(255) not null, price float, processing_date DATE not null)")

# %%
df_all_history_t_a.to_sql("yad2_history", conn, if_exists="append", index=False)

# %%
pd.read_sql("truncate table yad2_forsale_history", conn)

# %%
conn = connect_sql_alchemy()

# %%
import sqlalchemy
dtype = {
    "price": sqlalchemy.Integer,
    "processing_date": sqlalchemy.Date
}
df_all_history_t_a.to_sql("yad2_forsale_history", conn, if_exists="append", index=False, dtype=dtype)

# %%
pd.read_sql("select count(*) from yad2_forsale_history", conn)

# %%
df_all_history_t_a
